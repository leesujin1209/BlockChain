# %% [markdown]
# <a href="https://colab.research.google.com/github/leesujin1209/BlockChain/blob/main/6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 3.3.1 선형 회귀: LinearRegresstion
#
#
# (단항회귀)1차 방정식

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
# from sklearn.neighbors import KNeighborsRegressor
# knr = KNeighborsRegressor()
# knr.n_neighbors = 3         # 기본값: 5  이웃의 개수( = k)를 줄이면 극소에 예민해짐             = 과대적합
                              #                                늘리면 전반에 일반적인 패턴을 따름 = 과소적합

from sklearn.linear_model import LinearRegression
lr = LinearRegression()

perch_length = np.array([8.4, 13.7, 15.0, 16.2, 17.4, 18.0, 18.7, 19.0, 19.6, 20.0, 21.0,
       21.0, 21.0, 21.3, 22.0, 22.0, 22.0, 22.0, 22.0, 22.5, 22.5, 22.7,
       23.0, 23.5, 24.0, 24.0, 24.6, 25.0, 25.6, 26.5, 27.3, 27.5, 27.5,
       27.5, 28.0, 28.7, 30.0, 32.8, 34.5, 35.0, 36.5, 36.0, 37.0, 37.0,
       39.0, 39.0, 39.0, 40.0, 40.0, 40.0, 40.0, 42.0, 43.0, 43.0, 43.5,
       44.0])
perch_weight = np.array([5.9, 32.0, 40.0, 51.5, 70.0, 100.0, 78.0, 80.0, 85.0, 85.0, 110.0,
       115.0, 125.0, 130.0, 120.0, 120.0, 130.0, 135.0, 110.0, 130.0,
       150.0, 145.0, 150.0, 170.0, 225.0, 145.0, 188.0, 180.0, 197.0,
       218.0, 300.0, 260.0, 265.0, 250.0, 250.0, 300.0, 320.0, 514.0,
       556.0, 840.0, 685.0, 700.0, 700.0, 690.0, 900.0, 650.0, 820.0,
       850.0, 900.0, 1015.0, 820.0, 1100.0, 1000.0, 1100.0, 1000.0,
       1000.0])

train_input, test_input, train_target, test_target = train_test_split(perch_length, perch_weight, random_state=42)


train_input = train_input.reshape(-1, 1)
test_input = test_input.reshape(-1, 1)
# knr.fit(train_input, train_target)
lr.fit(train_input, train_target)

# print(knr.predict([[50]]))
print(lr.predict([[50]]))
print(lr.predict([[100]]))

print(lr.coef_, lr.intercept_)             #계수(기울기)(a), 편향(절편)(b)
# 계수와 편향을 모델 파라메타라고 하며 훈련은 최적의 모델 파라메타를 찾는 과정이다.
# 하이퍼 파라메타: 사람이 직접 입력하는 것으로 k-최근접 이웃에서 k가 해당된다.

plt.scatter(train_input, train_target)                                       # 훈련 세트의 산점도를 그립니다.
plt.plot([15, 50], [15*lr.coef_+lr.intercept_, 50*lr.coef_+lr.intercept_])   # 15에서 50까지 1차 방정식 그래프를 그립니다.
plt.scatter(50, 1241.8, marker='^')                                          # 50cm 농어 데이터
plt.xlabel('length')
plt.ylabel('weight')
plt.show()

print(lr.score(train_input, train_target))
print(lr.score(test_input, test_target))
# 과대적합
# Out:
# [1241.83860323]
# [3192.69585141]
# [39.01714496] -709.0186449535477
# 0.939846333997604
# 0.8247503123313558

# %% [markdown]
# ##3.3.1 파라미터와 하이퍼파라미터의 차이
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 3.3.2 다항회귀 선형회귀 2차 방정식

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

perch_length = np.array([8.4, 13.7, 15.0, 16.2, 17.4, 18.0, 18.7, 19.0, 19.6, 20.0, 21.0,
       21.0, 21.0, 21.3, 22.0, 22.0, 22.0, 22.0, 22.0, 22.5, 22.5, 22.7,
       23.0, 23.5, 24.0, 24.0, 24.6, 25.0, 25.6, 26.5, 27.3, 27.5, 27.5,
       27.5, 28.0, 28.7, 30.0, 32.8, 34.5, 35.0, 36.5, 36.0, 37.0, 37.0,
       39.0, 39.0, 39.0, 40.0, 40.0, 40.0, 40.0, 42.0, 43.0, 43.0, 43.5,
       44.0])
perch_weight = np.array([5.9, 32.0, 40.0, 51.5, 70.0, 100.0, 78.0, 80.0, 85.0, 85.0, 110.0,
       115.0, 125.0, 130.0, 120.0, 120.0, 130.0, 135.0, 110.0, 130.0,
       150.0, 145.0, 150.0, 170.0, 225.0, 145.0, 188.0, 180.0, 197.0,
       218.0, 300.0, 260.0, 265.0, 250.0, 250.0, 300.0, 320.0, 514.0,
       556.0, 840.0, 685.0, 700.0, 700.0, 690.0, 900.0, 650.0, 820.0,
       850.0, 900.0, 1015.0, 820.0, 1100.0, 1000.0, 1100.0, 1000.0,
       1000.0])

train_input, test_input, train_target, test_target = train_test_split(perch_length, perch_weight, random_state=42)


train_input = train_input.reshape(-1, 1)
test_input = test_input.reshape(-1, 1)

train_poly = np.column_stack((train_input ** 2, train_input))
test_poly = np.column_stack((test_input ** 2, test_input))

# print(train_input)
# print(train_poly)                  # 뒤에 있는 값 제곱 = 앞의 값

lr.fit(train_poly, train_target)
print(lr.predict([[50**2, 50]]))
# 기존 1차 방정식의 값은 1241이었으나
# 해당 결과가 1241보다 큰 것을 확인할 수 있다. (결과 값: 1573...)


lr = LinearRegression()
lr.fit(train_poly, train_target)
print(lr.coef_, lr.intercept_)

# 정확도 확인
print(lr.score(train_poly, train_target))
print(lr.score(test_poly, test_target))
# Out:
# [1573.98423528]
# [  1.01433211 -21.55792498] 116.0502107827827
# 0.9706807451768623
# 0.9775935108325122
